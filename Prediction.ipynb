# %%
import pandas as pd
matches = pd.read_csv("matches.csv",index_col=0)
matches
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 18  2023-12-22  20:00  Premier League  Matchweek 18  Fri  Away      D  1.0
# 19  2023-12-26  15:00  Premier League  Matchweek 19  Tue  Home      L  2.0
# 20  2023-12-30  15:00  Premier League  Matchweek 20  Sat  Away      L  0.0
# 22  2024-01-21  14:00  Premier League  Matchweek 21  Sun  Home      D  2.0
# 24  2024-01-30  20:00  Premier League  Matchweek 22  Tue  Away      L  2.0
#
#      ga         opponent  ...  match report  notes    sh  sot  dist   fk pk  \
# 0   1.0          Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0
# 1   1.0      Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0
# 2   1.0    Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0
# 3   0.0      Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0
# 4   1.0           Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0
# ..  ...              ...  ...           ...    ...   ...  ...   ...  ... ..
# 18  1.0      Aston Villa  ...  Match Report    NaN   5.0  2.0  19.7  0.0  0
# 19  3.0       Luton Town  ...  Match Report    NaN  21.0  4.0  16.3  1.0  0
# 20  2.0  Manchester City  ...  Match Report    NaN   4.0  2.0  14.9  0.0  0
# 22  2.0         West Ham  ...  Match Report    NaN  20.0  5.0  18.5  1.0  1
# 24  3.0   Crystal Palace  ...  Match Report    NaN   9.0  5.0  16.5  0.0  0
#
#    pkatt  season              team
# 0      0    2023         Liverpool
# 1      1    2023         Liverpool
# 2      0    2023         Liverpool
# 3      0    2023         Liverpool
# 4      0    2023         Liverpool
# ..   ...     ...               ...
# 18     0    2023  Sheffield United
# 19     0    2023  Sheffield United
# 20     0    2023  Sheffield United
# 22     1    2023  Sheffield United
# 24     0    2023  Sheffield United
#
# [447 rows x 27 columns]

# %%
matches.shape
# Out:
# (447, 27)

# %%
matches['team'].value_counts()
# Out:
# team
# Liverpool                   42
# Brighton and Hove Albion    22
# Everton                     22
# Nottingham Forest           22
# Crystal Palace              22
# Fulham                      22
# Arsenal                     22
# Sheffield United            22
# Newcastle United            22
# Aston Villa                 22
# Manchester United           21
# Chelsea                     21
# West Ham United             21
# Tottenham Hotspur           21
# Luton Town                  21
# Burnley                     21
# Wolverhampton Wanderers     21
# Bournemouth                 20
# Brentford                   20
# Manchester City             20
# Name: count, dtype: int64

# %%
matches['round'].value_counts()
# Out:
# round
# Matchweek 1     21
# Matchweek 11    21
# Matchweek 21    21
# Matchweek 20    21
# Matchweek 19    21
# Matchweek 16    21
# Matchweek 15    21
# Matchweek 14    21
# Matchweek 13    21
# Matchweek 2     21
# Matchweek 12    21
# Matchweek 10    21
# Matchweek 9     21
# Matchweek 8     21
# Matchweek 7     21
# Matchweek 6     21
# Matchweek 5     21
# Matchweek 4     21
# Matchweek 3     21
# Matchweek 17    19
# Matchweek 18    19
# Matchweek 22    10
# Name: count, dtype: int64

# %%
#cleaning data
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches['date']= pd.to_datetime(matches['date'])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["target"] = (matches["result"] == "W").astype("int")
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 18 2023-12-22  20:00  Premier League  Matchweek 18  Fri  Away      D  1.0
# 19 2023-12-26  15:00  Premier League  Matchweek 19  Tue  Home      L  2.0
# 20 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Away      L  0.0
# 22 2024-01-21  14:00  Premier League  Matchweek 21  Sun  Home      D  2.0
# 24 2024-01-30  20:00  Premier League  Matchweek 22  Tue  Away      L  2.0
#
#      ga         opponent  ...   fk  pk  pkatt  season              team  \
# 0   1.0          Chelsea  ...  0.0   0      0    2023         Liverpool
# 1   1.0      Bournemouth  ...  1.0   0      1    2023         Liverpool
# 2   1.0    Newcastle Utd  ...  1.0   0      0    2023         Liverpool
# 3   0.0      Aston Villa  ...  0.0   0      0    2023         Liverpool
# 4   1.0           Wolves  ...  0.0   0      0    2023         Liverpool
# ..  ...              ...  ...  ...  ..    ...     ...               ...
# 18  1.0      Aston Villa  ...  0.0   0      0    2023  Sheffield United
# 19  3.0       Luton Town  ...  1.0   0      0    2023  Sheffield United
# 20  2.0  Manchester City  ...  0.0   0      0    2023  Sheffield United
# 22  2.0         West Ham  ...  1.0   1      1    2023  Sheffield United
# 24  3.0   Crystal Palace  ...  0.0   0      0    2023  Sheffield United
#
#    venue_code opp_code hour  day_code  target
# 0           0        6   16         6       0
# 1           1        2   15         5       1
# 2           0       14   16         6       1
# 3           1        1   14         6       1
# 4           0       19   12         5       1
# ..        ...      ...  ...       ...     ...
# 18          0        1   20         4       0
# 19          1       11   15         1       0
# 20          0       12   15         5       0
# 22          1       18   14         6       0
# 24          0        7   20         1       0
#
# [447 rows x 32 columns]

# %%
#creating predictors for ml
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 18 2023-12-22  20:00  Premier League  Matchweek 18  Fri  Away      D  1.0
# 19 2023-12-26  15:00  Premier League  Matchweek 19  Tue  Home      L  2.0
# 20 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Away      L  0.0
# 22 2024-01-21  14:00  Premier League  Matchweek 21  Sun  Home      D  2.0
# 24 2024-01-30  20:00  Premier League  Matchweek 22  Tue  Away      L  2.0
#
#      ga         opponent  ...   fk  pk  pkatt  season              team  \
# 0   1.0          Chelsea  ...  0.0   0      0    2023         Liverpool
# 1   1.0      Bournemouth  ...  1.0   0      1    2023         Liverpool
# 2   1.0    Newcastle Utd  ...  1.0   0      0    2023         Liverpool
# 3   0.0      Aston Villa  ...  0.0   0      0    2023         Liverpool
# 4   1.0           Wolves  ...  0.0   0      0    2023         Liverpool
# ..  ...              ...  ...  ...  ..    ...     ...               ...
# 18  1.0      Aston Villa  ...  0.0   0      0    2023  Sheffield United
# 19  3.0       Luton Town  ...  1.0   0      0    2023  Sheffield United
# 20  2.0  Manchester City  ...  0.0   0      0    2023  Sheffield United
# 22  2.0         West Ham  ...  1.0   1      1    2023  Sheffield United
# 24  3.0   Crystal Palace  ...  0.0   0      0    2023  Sheffield United
#
#    venue_code opp_code hour  day_code  target
# 0           0        6   16         6       0
# 1           1        2   15         5       1
# 2           0       14   16         6       1
# 3           1        1   14         6       1
# 4           0       19   12         5       1
# ..        ...      ...  ...       ...     ...
# 18          0        1   20         4       0
# 19          1       11   15         1       0
# 20          0       12   15         5       0
# 22          1       18   14         6       0
# 24          0        7   20         1       0
#
# [447 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] > '2024-01-01']
test = matches[matches["date"] > '2024-01-01']
predictors = ["venue_code", "opp_code", "hour", "day_code"]
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)
error
# Out:
# 0.7575757575757576

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0  1
# actual
# 0          23  0
# 1           8  2

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 1.0

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 23 2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 25 2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 26 2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 27 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 29 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away      W  3.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 5   1.0           Fulham  ...         5       1    2.000000    0.333333
# 6   1.0         West Ham  ...         5       1    2.666667    0.666667
# 8   0.0  Nott'ham Forest  ...         5       1    3.333333    1.000000
# 10  2.0           Wolves  ...         5       0    3.333333    0.666667
# 12  1.0          Arsenal  ...         6       0    2.000000    1.000000
# 13  1.0         Brighton  ...         5       1    1.000000    1.000000
# 15  0.0   Manchester Utd  ...         6       1    1.000000    1.333333
# 16  1.0      Bournemouth  ...         5       1    1.666667    0.666667
# 18  4.0          Chelsea  ...         6       0    3.666667    0.666667
# 19  1.0        Liverpool  ...         5       0    4.333333    1.666667
# 21  3.0        Tottenham  ...         6       0    3.666667    2.000000
# 22  1.0      Aston Villa  ...         2       0    2.666667    2.666667
# 23  1.0       Luton Town  ...         6       1    1.333333    1.666667
# 25  2.0   Crystal Palace  ...         5       0    1.666667    1.666667
# 26  1.0          Everton  ...         2       1    1.333333    1.333333
# 27  0.0    Sheffield Utd  ...         5       1    2.333333    1.333333
# 29  2.0    Newcastle Utd  ...         5       1    2.333333    1.000000
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 5   20.000000    7.000000    16.366667   0.666667    0.000000       0.333333
# 6   16.333333    5.666667    16.666667   0.666667    0.333333       0.666667
# 8   21.333333    8.666667    16.166667   1.000000    0.333333       0.666667
# 10  14.000000    7.000000    16.133333   1.000000    0.333333       0.333333
# 12  19.666667    8.333333    17.633333   1.333333    0.000000       0.000000
# 13  11.333333    4.000000    17.133333   1.000000    0.000000       0.000000
# 15  12.333333    4.333333    17.666667   0.666667    0.000000       0.000000
# 16  11.333333    4.666667    16.966667   1.000000    0.333333       0.333333
# 18  17.000000    7.333333    17.466667   1.000000    0.333333       0.333333
# 19  18.333333    8.666667    16.733333   1.000000    0.666667       0.666667
# 21  17.000000    7.333333    16.433333   0.666667    0.333333       0.333333
# 22  15.666667    6.000000    15.433333   0.666667    0.333333       0.333333
# 23  11.666667    3.666667    12.366667   0.333333    0.000000       0.000000
# 25  12.333333    4.000000    13.166667   0.333333    0.000000       0.000000
# 26  13.000000    5.666667    14.766667   0.333333    0.000000       0.000000
# 27  19.666667    7.666667    18.800000   0.666667    0.333333       0.333333
# 29  19.666667    7.000000    18.366667   0.333333    0.333333       0.333333
#
# [17 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2023-09-03  16:30  Premier League   Matchweek 4
#                         5  2023-09-17  16:30  Premier League   Matchweek 5
#                         7  2023-09-24  14:00  Premier League   Matchweek 6
#                         9  2023-09-30  15:00  Premier League   Matchweek 7
#                         11 2023-10-08  16:30  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 18 2023-12-17  14:00  Premier League  Matchweek 17
#                         19 2023-12-24  13:00  Premier League  Matchweek 18
#                         20 2023-12-27  19:30  Premier League  Matchweek 19
#                         21 2023-12-30  15:00  Premier League  Matchweek 20
#                         24 2024-01-22  19:45  Premier League  Matchweek 21
#
#                             day venue result   gf   ga         opponent  ...  \
# team                                                                     ...
# Arsenal                 4   Sun  Home      W  3.0  1.0   Manchester Utd  ...
#                         5   Sun  Away      W  1.0  0.0          Everton  ...
#                         7   Sun  Home      D  2.0  2.0        Tottenham  ...
#                         9   Sat  Away      W  4.0  0.0      Bournemouth  ...
#                         11  Sun  Home      W  1.0  0.0  Manchester City  ...
# ...                         ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 18  Sun  Away      L  0.0  3.0         West Ham  ...
#                         19  Sun  Home      W  2.0  1.0          Chelsea  ...
#                         20  Wed  Away      W  4.0  1.0        Brentford  ...
#                         21  Sat  Home      W  3.0  0.0          Everton  ...
#                         24  Mon  Away      D  0.0  0.0         Brighton  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4          6       1    1.666667    1.000000
#                         5          6       1    2.000000    1.000000
#                         7          6       0    2.000000    1.000000
#                         9          5       1    2.000000    1.000000
#                         11         6       1    2.333333    0.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 18         6       0    1.000000    1.000000
#                         19         6       1    0.666667    1.333333
#                         20         2       1    1.000000    1.666667
#                         21         5       1    2.000000    1.666667
#                         24         0       0    3.000000    0.666667
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4   15.333333    6.000000    16.433333   0.000000
#                         5   16.000000    5.333333    15.066667   0.000000
#                         7   16.000000    6.000000    15.400000   0.000000
#                         9   14.000000    4.333333    16.433333   0.000000
#                         11  12.666667    4.666667    16.600000   0.000000
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 18   7.666667    3.666667    13.933333   0.333333
#                         19  10.333333    3.666667    17.166667   0.333333
#                         20  12.666667    4.333333    17.466667   0.333333
#                         21  13.000000    4.666667    18.333333   0.333333
#                         24  12.333333    5.666667    15.966667   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 4     0.666667       0.666667
#                         5     0.666667       0.666667
#                         7     0.333333       0.333333
#                         9     0.333333       0.333333
#                         11    1.000000       1.000000
# ...                                ...            ...
# Wolverhampton Wanderers 18    0.000000       0.000000
#                         19    0.000000       0.000000
#                         20    0.000000       0.000000
#                         21    0.000000       0.000000
#                         24    0.000000       0.000000
#
# [387 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W  3.0
# 5  2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W  1.0
# 7  2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      D  2.0
# 9  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      W  4.0
# 11 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Home      W  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 18 2023-12-17  14:00  Premier League  Matchweek 17  Sun  Away      L  0.0
# 19 2023-12-24  13:00  Premier League  Matchweek 18  Sun  Home      W  2.0
# 20 2023-12-27  19:30  Premier League  Matchweek 19  Wed  Away      W  4.0
# 21 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  3.0
# 24 2024-01-22  19:45  Premier League  Matchweek 21  Mon  Away      D  0.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 4   1.0   Manchester Utd  ...         6       1    1.666667    1.000000
# 5   0.0          Everton  ...         6       1    2.000000    1.000000
# 7   2.0        Tottenham  ...         6       0    2.000000    1.000000
# 9   0.0      Bournemouth  ...         5       1    2.000000    1.000000
# 11  0.0  Manchester City  ...         6       1    2.333333    0.666667
# ..  ...              ...  ...       ...     ...         ...         ...
# 18  3.0         West Ham  ...         6       0    1.000000    1.000000
# 19  1.0          Chelsea  ...         6       1    0.666667    1.333333
# 20  1.0        Brentford  ...         2       1    1.000000    1.666667
# 21  0.0          Everton  ...         5       1    2.000000    1.666667
# 24  0.0         Brighton  ...         0       0    3.000000    0.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4   15.333333    6.000000    16.433333   0.000000    0.666667       0.666667
# 5   16.000000    5.333333    15.066667   0.000000    0.666667       0.666667
# 7   16.000000    6.000000    15.400000   0.000000    0.333333       0.333333
# 9   14.000000    4.333333    16.433333   0.000000    0.333333       0.333333
# 11  12.666667    4.666667    16.600000   0.000000    1.000000       1.000000
# ..        ...         ...          ...        ...         ...            ...
# 18   7.666667    3.666667    13.933333   0.333333    0.000000       0.000000
# 19  10.333333    3.666667    17.166667   0.333333    0.000000       0.000000
# 20  12.666667    4.333333    17.466667   0.333333    0.000000       0.000000
# 21  13.000000    4.666667    18.333333   0.333333    0.000000       0.000000
# 24  12.333333    5.666667    15.966667   0.333333    0.000000       0.000000
#
# [387 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.6

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined.head(10)
# Out:
#      actual  predicted       date                      team         opponent  \
# 17        1          1 2024-01-20                   Arsenal   Crystal Palace
# 18        1          1 2024-01-30                   Arsenal  Nott'ham Forest
# 36        0          0 2024-01-14               Aston Villa          Everton
# 37        0          0 2024-01-30               Aston Villa    Newcastle Utd
# 54        0          0 2024-01-21               Bournemouth        Liverpool
# 71        1          0 2024-01-20                 Brentford  Nott'ham Forest
# 88        0          0 2024-01-02  Brighton and Hove Albion         West Ham
# 89        0          1 2024-01-22  Brighton and Hove Albion           Wolves
# 90        0          1 2024-01-30  Brighton and Hove Albion       Luton Town
# 108       0          0 2024-01-12                   Burnley       Luton Town
#
#     result
# 17       W
# 18       W
# 36       D
# 37       L
# 54       L
# 71       W
# 88       D
# 89       D
# 90       L
# 108      D

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#     actual_x  predicted_x       date                    team_x  \
# 0          1            1 2024-01-20                   Arsenal
# 1          1            1 2024-01-30                   Arsenal
# 2          0            0 2024-01-14               Aston Villa
# 3          0            0 2024-01-30               Aston Villa
# 4          0            0 2024-01-21               Bournemouth
# 5          0            0 2024-01-21               Bournemouth
# 6          1            0 2024-01-20                 Brentford
# 7          0            0 2024-01-02  Brighton and Hove Albion
# 8          0            1 2024-01-22  Brighton and Hove Albion
# 9          0            1 2024-01-30  Brighton and Hove Albion
# 10         0            0 2024-01-12                   Burnley
# 11         1            1 2024-01-13                   Chelsea
# 12         0            0 2024-01-20            Crystal Palace
# 13         1            0 2024-01-30            Crystal Palace
# 14         0            0 2024-01-14                   Everton
# 15         0            0 2024-01-30                   Everton
# 16         0            0 2024-01-13                    Fulham
# 17         0            1 2024-01-30                    Fulham
# 18         1            1 2024-01-21                 Liverpool
# 19         1            1 2024-01-21                 Liverpool
# 20         0            1 2024-01-12                Luton Town
# 21         1            1 2024-01-30                Luton Town
# 22         1            0 2024-01-13           Manchester City
# 23         0            0 2024-01-14         Manchester United
# 24         0            0 2024-01-13          Newcastle United
# 25         1            0 2024-01-30          Newcastle United
# 26         0            0 2024-01-14         Tottenham Hotspur
# 27         0            0 2024-01-02           West Ham United
# 28         0            0 2024-01-21           West Ham United
# 29         0            0 2024-01-22   Wolverhampton Wanderers
#
#          opponent_x result_x       new_team_x  actual_y  predicted_y  \
# 0    Crystal Palace        W          Arsenal         0            0
# 1   Nott'ham Forest        W          Arsenal         0            0
# 2           Everton        D      Aston Villa         0            0
# 3     Newcastle Utd        L      Aston Villa         1            0
# 4         Liverpool        L      Bournemouth         1            1
# 5         Liverpool        L      Bournemouth         1            1
# 6   Nott'ham Forest        W        Brentford         0            0
# 7          West Ham        D         Brighton         0            0
# 8            Wolves        D         Brighton         0            0
# 9        Luton Town        L         Brighton         1            1
# 10       Luton Town        D          Burnley         0            1
# 11           Fulham        W          Chelsea         0            0
# 12          Arsenal        L   Crystal Palace         1            1
# 13    Sheffield Utd        W   Crystal Palace         0            0
# 14      Aston Villa        D          Everton         0            0
# 15           Fulham        D          Everton         0            1
# 16          Chelsea        L           Fulham         1            1
# 17          Everton        D           Fulham         0            0
# 18      Bournemouth        W        Liverpool         0            0
# 19      Bournemouth        W        Liverpool         0            0
# 20          Burnley        D       Luton Town         0            0
# 21         Brighton        W       Luton Town         0            1
# 22    Newcastle Utd        W  Manchester City         0            0
# 23        Tottenham        D   Manchester Utd         0            0
# 24  Manchester City        L    Newcastle Utd         1            0
# 25      Aston Villa        W    Newcastle Utd         0            0
# 26   Manchester Utd        D        Tottenham         0            0
# 27         Brighton        D         West Ham         0            0
# 28    Sheffield Utd        D         West Ham         0            0
# 29         Brighton        D           Wolves         0            1
#
#                       team_y       opponent_y result_y         new_team_y
# 0             Crystal Palace          Arsenal        L     Crystal Palace
# 1          Nottingham Forest          Arsenal        L  Nottingham Forest
# 2                    Everton      Aston Villa        D            Everton
# 3           Newcastle United      Aston Villa        W      Newcastle Utd
# 4                  Liverpool      Bournemouth        W          Liverpool
# 5                  Liverpool      Bournemouth        W          Liverpool
# 6          Nottingham Forest        Brentford        L  Nottingham Forest
# 7            West Ham United         Brighton        D           West Ham
# 8    Wolverhampton Wanderers         Brighton        D             Wolves
# 9                 Luton Town         Brighton        W         Luton Town
# 10                Luton Town          Burnley        D         Luton Town
# 11                    Fulham          Chelsea        L             Fulham
# 12                   Arsenal   Crystal Palace        W            Arsenal
# 13          Sheffield United   Crystal Palace        L   Sheffield United
# 14               Aston Villa          Everton        D        Aston Villa
# 15                    Fulham          Everton        D             Fulham
# 16                   Chelsea           Fulham        W            Chelsea
# 17                   Everton           Fulham        D            Everton
# 18               Bournemouth        Liverpool        L        Bournemouth
# 19               Bournemouth        Liverpool        L        Bournemouth
# 20                   Burnley       Luton Town        D            Burnley
# 21  Brighton and Hove Albion       Luton Town        L           Brighton
# 22          Newcastle United  Manchester City        L      Newcastle Utd
# 23         Tottenham Hotspur   Manchester Utd        D          Tottenham
# 24           Manchester City    Newcastle Utd        W    Manchester City
# 25               Aston Villa    Newcastle Utd        L        Aston Villa
# 26         Manchester United        Tottenham        D     Manchester Utd
# 27  Brighton and Hove Albion         West Ham        D           Brighton
# 28          Sheffield United         West Ham        D   Sheffield United
# 29  Brighton and Hove Albion           Wolves        D           Brighton

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    5
# 0    3
# Name: count, dtype: int64
